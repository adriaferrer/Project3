# %%
import pandas as pd
from sqlalchemy import create_engine
from nba_api.stats.endpoints import commonplayerinfo
from nba_api.stats.endpoints import leaguedashplayerbiostats
from nba_api.stats.static import teams
from nba_api.stats.static import players

# %%
engine = create_engine('mysql+pymysql://root:paugasol@35.246.57.187/NBA')
df_players_salaries = pd.read_sql('players',con=engine)

# %%
players_id= list(df_players_salaries['player_id'])

# %%
players_id[20]
# Out:
# 203954

# %%
commonplayerinfo.CommonPlayerInfo(f'{player}').get_data_frames()[0]
# Out:
#    PERSON_ID FIRST_NAME LAST_NAME DISPLAY_FIRST_LAST DISPLAY_LAST_COMMA_FIRST  \
# 0     201960    DeMarre   Carroll    DeMarre Carroll         Carroll, DeMarre
#
#   DISPLAY_FI_LAST            BIRTHDATE    SCHOOL COUNTRY LAST_AFFILIATION  \
# 0      D. Carroll  1986-07-27T00:00:00  Missouri     USA     Missouri/USA
#
#    ... TEAM_CITY       PLAYERCODE  FROM_YEAR TO_YEAR DLEAGUE_FLAG NBA_FLAG  \
# 0  ...  Brooklyn  demarre_carroll       2009    2018            Y        Y
#
#    GAMES_PLAYED_FLAG DRAFT_YEAR DRAFT_ROUND DRAFT_NUMBER
# 0                  Y       2009           1           27
#
# [1 rows x 30 columns]

# %%
player_info = pd.DataFrame()
for player in players_id[21:31]:
    print(player)
    df = commonplayerinfo.CommonPlayerInfo(f'{player}').get_data_frames()[0]
    print(df)
    player_info = player_info.append(df)
    print(player_info)
# Out:
# 203952
#    PERSON_ID FIRST_NAME LAST_NAME DISPLAY_FIRST_LAST DISPLAY_LAST_COMMA_FIRST  \
# 0     203952     Andrew   Wiggins     Andrew Wiggins          Wiggins, Andrew
#
#   DISPLAY_FI_LAST            BIRTHDATE  SCHOOL COUNTRY LAST_AFFILIATION  ...  \
# 0      A. Wiggins  1995-02-23T00:00:00  Kansas  Canada    Kansas/Canada  ...
#
#    TEAM_CITY      PLAYERCODE  FROM_YEAR TO_YEAR DLEAGUE_FLAG NBA_FLAG  \
# 0  Minnesota  andrew_wiggins       2014    2018            N        Y
#
#    GAMES_PLAYED_FLAG DRAFT_YEAR DRAFT_ROUND DRAFT_NUMBER
# 0                  Y       2014           1            1
#
# [1 rows x 30 columns]
#    PERSON_ID FIRST_NAME LAST_NAME DISPLAY_FIRST_LAST DISPLAY_LAST_COMMA_FIRST  \
# 0     203952     Andrew   Wiggins     Andrew Wiggins          Wiggins, Andrew
#
#   DISPLAY_FI_LAST            BIRTHDATE  SCHOOL COUNTRY LAST_AFFILIATION  ...  \
# 0      A. Wiggins  1995-02-23T00:00:00  Kansas  Canada    Kansas/Canada  ...
#
# ...

# %%
player_info
# Out:
#    PERSON_ID FIRST_NAME      LAST_NAME     DISPLAY_FIRST_LAST  \
# 0     203952     Andrew        Wiggins         Andrew Wiggins
# 0     203076    Anthony          Davis          Anthony Davis
# 0     203083      Andre       Drummond         Andre Drummond
# 0     203078    Bradley           Beal           Bradley Beal
# 0     202355     Hassan      Whiteside       Hassan Whiteside
# 0       2730     Dwight         Howard          Dwight Howard
# 0     203507    Giannis  Antetokounmpo  Giannis Antetokounmpo
# 0     203500     Steven          Adams           Steven Adams
# 0     201567      Kevin           Love             Kevin Love
# 0     201188       Marc          Gasol             Marc Gasol
#
#   DISPLAY_LAST_COMMA_FIRST   DISPLAY_FI_LAST            BIRTHDATE  \
# 0          Wiggins, Andrew        A. Wiggins  1995-02-23T00:00:00
# 0           Davis, Anthony          A. Davis  1993-03-11T00:00:00
# 0          Drummond, Andre       A. Drummond  1993-08-10T00:00:00
# ...

# %%
player_info2 = player_info2.append(player_info)

# %%
player_info2 = player_info2.reset_index()

# %%
player_info2.drop(columns='index',inplace=True)

# %%
player_info3 = player_info2.drop(columns=['FIRST_NAME','LAST_NAME','DISPLAY_LAST_COMMA_FIRST','DISPLAY_FI_LAST','BIRTHDATE','SCHOOL','COUNTRY','LAST_AFFILIATION','PLAYERCODE','FROM_YEAR','TO_YEAR','DLEAGUE_FLAG','NBA_FLAG','GAMES_PLAYED_FLAG','DRAFT_YEAR','DRAFT_ROUND','DRAFT_NUMBER','HEIGHT','WEIGHT','SEASON_EXP','JERSEY','POSITION','ROSTERSTATUS'])

# %%
player_info4 = player_info3[['PERSON_ID','DISPLAY_FIRST_LAST','TEAM_ID']]

# %%
player_info4.rename(columns={'PERSON_ID':'player_id','DISPLAY_FIRST_LAST':'full_name','TEAM_ID':'team_id'},inplace=True)
# Out:
# /Users/adriaferrer/Library/Python/3.7/lib/python/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
engine = create_engine('mysql+pymysql://root:paugasol@35.246.57.187/NBA')
df_players_DB = pd.read_sql('players',con=engine)

# %%
df_players_DB.head()
# Out:
#    index  player_id          full_name  birthdate country  height  weight  \
# 0      0     201939      Stephen Curry 1988-03-14     USA     6.3   190.0
# 1      1     201566  Russell Westbrook 1988-11-12     USA     6.3   200.0
# 2      2     101108         Chris Paul 1985-05-06     USA     6.0   175.0
# 3      3       2544       LeBron James 1984-12-30     USA     6.8   250.0
# 4      4     201933      Blake Griffin 1989-03-16     USA     6.1   250.0
#
#   position rosterstatus  from_year  to_year  draft_year  draft_round  \
# 0    Guard       Active       2009     2018        2009            1
# 1    Guard       Active       2008     2018        2008            1
# 2    Guard       Active       2005     2018        2005            1
# 3  Forward       Active       2003     2018        2003            1
# 4  Forward       Active       2009     2018        2009            1
#
#    draft_number
# 0             7
# 1             4
# 2             4
# 3             1
# 4             1

# %%
player_info4.head()
# Out:
#    player_id         full_name     team_id
# 0     202718  Chandler Parsons  1610612763
# 1     203084   Harrison Barnes  1610612758
# 2     201587     Nicolas Batum  1610612766
# 3     202695     Kawhi Leonard  1610612761
# 4     201599    DeAndre Jordan  1610612752

# %%
df_players_DB = df_players_DB.merge(player_info4,how='left')

# %%
df_players_DB = df_players_DB.reset_index(drop=True).drop(columns='index')

# %%
df_players_DB.to_sql('players',con=engine,if_exists='replace', index=True)
