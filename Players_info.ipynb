# %%
import pandas as pd
from sqlalchemy import create_engine
from nba_api.stats.endpoints import commonplayerinfo
from nba_api.stats.endpoints import leaguedashplayerbiostats
from nba_api.stats.static import teams
from nba_api.stats.static import players

# %%
engine = create_engine('mysql+pymysql://root:paugasol@35.246.57.187/NBA')
df_players_salaries = pd.read_sql('salaries',con=engine)

# %%
players_id= list(df_players_salaries['id'])

# %%
players_id[113:120]
# Out:
# [2216, 202692, 201600, 203935, 203994, 202697, 203503]

# %%
player_perf = pd.DataFrame()
for player in players_id[113:]:
    print(player)
    df = pd.DataFrame(commonplayerinfo.CommonPlayerInfo(f'{player}').get_data_frames()[1])
    print(df)
    player_perf = player_perf.append(df)
    print(player_perf)
# Out:
# 2216
#    PLAYER_ID    PLAYER_NAME TimeFrame   PTS  AST  REB  ALL_STAR_APPEARANCES
# 0       2216  Zach Randolph    career  16.6  1.8  9.1                     2
#    PLAYER_ID    PLAYER_NAME TimeFrame   PTS  AST  REB  ALL_STAR_APPEARANCES
# 0       2216  Zach Randolph    career  16.6  1.8  9.1                     2
# 202692
#    PLAYER_ID PLAYER_NAME TimeFrame  PTS  AST  REB    PIE
# 0     202692  Alec Burks   2018-19  9.0  2.0  3.7  0.091
#    ALL_STAR_APPEARANCES  AST    PIE  PLAYER_ID    PLAYER_NAME   PTS  REB  \
# 0                   2.0  1.8    NaN       2216  Zach Randolph  16.6  9.1
# 0                   NaN  2.0  0.091     202692     Alec Burks   9.0  3.7
#
#   TimeFrame
# 0    career
# 0   2018-19
# 201600
# /Users/adriaferrer/Library/Python/3.7/lib/python/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# ...

# %%
player_perf.head()
# Out:
#    AST    PIE PLAYER_ID    PLAYER_NAME   PTS   REB TimeFrame
# 0  1.8    NaN      2216  Zach Randolph  16.6   9.1    career
# 0  2.0  0.091    202692     Alec Burks   9.0   3.7   2018-19
# 0  0.6    NaN    201600      Omer Asik   5.3   7.1    career
# 0  4.1  0.080    203935   Marcus Smart   8.8   3.0   2018-19
# 0  3.3  0.144    203994   Jusuf Nurkic  15.4  10.4   2018-19

# %%
player_perf = player_perf.reset_index(drop=True)

# %%
player_perf.head()
# Out:
#    AST    PIE PLAYER_ID    PLAYER_NAME   PTS   REB TimeFrame
# 0  1.8    NaN      2216  Zach Randolph  16.6   9.1    career
# 1  2.0  0.091    202692     Alec Burks   9.0   3.7   2018-19
# 2  0.6    NaN    201600      Omer Asik   5.3   7.1    career
# 3  4.1  0.080    203935   Marcus Smart   8.8   3.0   2018-19
# 4  3.3  0.144    203994   Jusuf Nurkic  15.4  10.4   2018-19

# %%
player_perf.to_sql('performance', con=engine,if_exists='append', index=True)

# %% [markdown]
# # Comprobacion indices

# %%
players_id
player_id_inDB = pd.read_sql('performance',con=engine)

# %%
import numpy as np

# %%
missing_player_ids = np.setdiff1d(players_id,player_id_inDB['PLAYER_ID'])

# %%
len(list(missing_player_ids))
# Out:
# 423
