# %% [markdown]
# # Cleaning 'Salaries'

# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %%
engine = create_engine('mysql+pymysql://root:paugasol@35.246.57.187/NBA')

# %%
salaries_df = pd.read_sql('salaries',con=engine)

# %%
salaries_df.head()
# Out:
#    index          Full name      2018/19      2019/20      2020/21  \
# 0      0      Stephen Curry  $37,457,154  $40,231,758  $43,006,362
# 1      1  Russell Westbrook  $35,665,000  $38,150,000  $40,600,000
# 2      2         Chris Paul  $35,654,150  $38,506,482  $41,358,814
# 3      3       LeBron James  $35,654,150  $37,436,858  $39,219,566
# 4      4      Blake Griffin  $31,873,932  $34,234,964  $36,595,996
#
#        2021/22 2022/23 2023/24      id
# 0  $45,780,966      $0      $0  201939
# 1                           $0  201566
# 2  $44,211,146      $0      $0  101108
# 3  $41,002,274      $0      $0    2544
# 4  $38,957,028      $0      $0  201933

# %%
salaries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485 entries, 0 to 484
# Data columns (total 9 columns):
# index        485 non-null int64
# Full name    485 non-null object
# 2018/19      485 non-null object
# 2019/20      485 non-null object
# 2020/21      485 non-null object
# 2021/22      485 non-null object
# 2022/23      485 non-null object
# 2023/24      485 non-null object
# id           485 non-null int64
# dtypes: int64(2), object(7)
# memory usage: 34.2+ KB

# %% [markdown]
# ## Dollars to int

# %%
salaries_df['2018/19'][0].strip('$').replace(',','')
# Out:
# '37457154'

# %%
i=0
for salary in salaries_df['2018/19']:
    salaries_df['2018/19'][i] = salary.strip('$').replace(',','')
    i += 1
salaries_df['2018/19']
# Out:
# /usr/local/Cellar/ipython/7.2.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0      37457154
# 1      35665000
# 2      35654150
# 3      35654150
# 4      31873932
# 5      31214295
# 6      31000000
# 7      30570000
# 8      30560700
# 9      30521115
# 10     30000000
# 11     29230769
# 12     28928710
# 13     27977689
# 14     27928140
# 15     27739975
# 16     26837720
# 17     26386111
# 18     25759766
# 19     25467250
# 20     25467250
# 21     25467250
# 22     25434263
# 23     25434262
# 24     25434262
# 25     24434262
# 26     24256725
# 27     24157304
# 28     24157304
# 29     24119025
#          ...
# 455       77250
# 456       77250
# ...

# %%
salaries_df['2018/19'] = salaries_df['2018/19'].astype('int64')

# %%
i=0
for salary in salaries_df['2019/20']:
    salaries_df['2019/20'][i] = salary.strip('$').replace(',','')
    i += 1
# Out:
# /usr/local/Cellar/ipython/7.2.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
i=0
for salary in salaries_df['2020/21']:
    salaries_df['2020/21'][i] = salary.strip('$').replace(',','')
    i += 1
# Out:
# /usr/local/Cellar/ipython/7.2.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
i=0
for salary in salaries_df['2021/22']:
    salaries_df['2021/22'][i] = salary.strip('$').replace(',','')
    i += 1
# Out:
# /usr/local/Cellar/ipython/7.2.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
i=0
for salary in salaries_df['2022/23']:
    salaries_df['2022/23'][i] = salary.strip('$').replace(',','')
    i += 1
# Out:
# /usr/local/Cellar/ipython/7.2.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
i=0
for salary in salaries_df['2023/24']:
    salaries_df['2023/24'][i] = salary.strip('$').replace(',','')
    i += 1
# Out:
# /usr/local/Cellar/ipython/7.2.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
salaries_df.tail()
# Out:
#      index       Full name  2018/19 2019/20 2020/21 2021/22 2022/23 2023/24  \
# 480    480    Jordan McRae    77250       0       0       0       0       0
# 481    481  Devin Robinson    77250       0       0       0       0       0
# 482    482    Kobi Simmons    76236       0       0       0       0       0
# 483    483   Scotty Hopson    76236       0       0       0       0       0
# 484    484   Emanuel Terry    47370       0       0       0       0       0
#
#           id
# 480   203895
# 481  1628421
# 482  1628424
# 483   203816
# 484  1629150

# %%
salaries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485 entries, 0 to 484
# Data columns (total 9 columns):
# index        485 non-null int64
# Full name    485 non-null object
# 2018/19      485 non-null int64
# 2019/20      485 non-null object
# 2020/21      485 non-null object
# 2021/22      485 non-null object
# 2022/23      485 non-null object
# 2023/24      485 non-null object
# id           485 non-null int64
# dtypes: int64(3), object(6)
# memory usage: 34.2+ KB

# %%
salaries_df['2019/20'] = salaries_df['2019/20'].replace('',0)

# %%
salaries_df['2019/20'] = salaries_df['2019/20'].astype('int64')

# %%
salaries_df['2020/21'] = salaries_df['2020/21'].replace('',0)
salaries_df['2020/21'] = salaries_df['2020/21'].astype('int64')

# %%
salaries_df['2021/22'] = salaries_df['2021/22'].replace('',0)
salaries_df['2021/22'] = salaries_df['2021/22'].astype('int64')

# %%
salaries_df['2022/23'] = salaries_df['2022/23'].replace('',0)
salaries_df['2022/23'] = salaries_df['2022/23'].astype('int64')

# %%
salaries_df['2023/24'] = salaries_df['2023/24'].replace('',0)
salaries_df['2023/24'] = salaries_df['2023/24'].astype('int64')

# %%
salaries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485 entries, 0 to 484
# Data columns (total 9 columns):
# index        485 non-null int64
# Full name    485 non-null object
# 2018/19      485 non-null int64
# 2019/20      485 non-null int64
# 2020/21      485 non-null int64
# 2021/22      485 non-null int64
# 2022/23      485 non-null int64
# 2023/24      485 non-null int64
# id           485 non-null int64
# dtypes: int64(8), object(1)
# memory usage: 34.2+ KB

# %%
salaries_df.to_sql('salaries', con=engine,if_exists='replace', index=True)

# %% [markdown]
# # Restructuring salaries

# %%
salaries_df = pd.read_sql('salaries',con=engine)

# %%
salaries_df.head()
# Out:
#    level_0  index          Full name   2018/19   2019/20   2020/21   2021/22  \
# 0        0      0      Stephen Curry  37457154  40231758  43006362  45780966
# 1        1      1  Russell Westbrook  35665000  38150000  40600000         0
# 2        2      2         Chris Paul  35654150  38506482  41358814  44211146
# 3        3      3       LeBron James  35654150  37436858  39219566  41002274
# 4        4      4      Blake Griffin  31873932  34234964  36595996  38957028
#
#    2022/23  2023/24      id
# 0        0        0  201939
# 1        0        0  201566
# 2        0        0  101108
# 3        0        0    2544
# 4        0        0  201933

# %%
salaries_df['level_0'] = salaries_df['id']

# %%
salaries_df.rename(columns={'level_0':'player_id'},inplace=True)

# %%
salaries_df.drop(columns=['Full name'],inplace=True)

# %%
salaries_df.head()
# Out:
#    player_id   2018/19   2019/20   2020/21   2021/22  2022/23  2023/24
# 0     201939  37457154  40231758  43006362  45780966        0        0
# 1     201566  35665000  38150000  40600000         0        0        0
# 2     101108  35654150  38506482  41358814  44211146        0        0
# 3       2544  35654150  37436858  39219566  41002274        0        0
# 4     201933  31873932  34234964  36595996  38957028        0        0

# %%
salaries_df['season'] = pd.Series()

# %%
salaries_df.head()
# Out:
#    player_id   2018/19   2019/20   2020/21   2021/22  2022/23  2023/24  season
# 0     201939  37457154  40231758  43006362  45780966        0        0     NaN
# 1     201566  35665000  38150000  40600000         0        0        0     NaN
# 2     101108  35654150  38506482  41358814  44211146        0        0     NaN
# 3       2544  35654150  37436858  39219566  41002274        0        0     NaN
# 4     201933  31873932  34234964  36595996  38957028        0        0     NaN

# %%
salaries_df = salaries_df[['player_id','season','2018/19','2019/20','2020/21','2021/22','2022/23','2023/24']]

# %%
salaries_stacked_df = pd.DataFrame(salaries_df.reset_index().set_index(['index', 'player_id']).stack())

# %%
salaries_stacked_df = salaries_stacked_df.reset_index().drop(columns='index')

# %%
salaries_stacked_df = salaries_stacked_df.rename(columns={'level_2':'season'})

# %%
salaries_stacked_df = salaries_stacked_df.rename(columns={0:'salary'})

# %%
salaries_stacked_df.head()
# Out:
#    player_id   season      salary
# 0     201939  2018/19  37457154.0
# 1     201939  2019/20  40231758.0
# 2     201939  2020/21  43006362.0
# 3     201939  2021/22  45780966.0
# 4     201939  2022/23         0.0

# %%
salaries_stacked_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2910 entries, 0 to 2909
# Data columns (total 3 columns):
# player_id    2910 non-null int64
# season       2910 non-null object
# salary       2910 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 68.3+ KB

# %%
salaries_stacked_df.to_sql('salaries', con=engine,if_exists='replace', index=True)

# %% [markdown]
# # Cleaning 'players'

# %%
players = pd.read_sql('players',con=engine)

# %%
players.head()
# Out:
#    index  PERSON_ID DISPLAY_FIRST_LAST            BIRTHDATE COUNTRY HEIGHT  \
# 0      0     201939      Stephen Curry  1988-03-14T00:00:00     USA    6-3
# 1      0     201566  Russell Westbrook  1988-11-12T00:00:00     USA    6-3
# 2      0     101108         Chris Paul  1985-05-06T00:00:00     USA    6-0
# 3      0       2544       LeBron James  1984-12-30T00:00:00     USA    6-8
# 4      0     201933      Blake Griffin  1989-03-16T00:00:00     USA   6-10
#
#   WEIGHT POSITION ROSTERSTATUS  FROM_YEAR  TO_YEAR DRAFT_YEAR DRAFT_ROUND  \
# 0    190    Guard       Active     2009.0   2018.0       2009           1
# 1    200    Guard       Active     2008.0   2018.0       2008           1
# 2    175    Guard       Active     2005.0   2018.0       2005           1
# 3    250  Forward       Active     2003.0   2018.0       2003           1
# 4    250  Forward       Active     2009.0   2018.0       2009           1
#
#   DRAFT_NUMBER
# 0            7
# 1            4
# 2            4
# ...

# %%
players.rename(columns={'PERSON_ID':'player_id','DISPLAY_FIRST_LAST':'full_name'}, inplace=True)

# %%
players = players.drop(columns='index')

# %%
players.rename(columns={'BIRTHDATE':'birthdate','COUNTRY':'country','HEIGHT':'height','WEIGHT':'weight','POSITION':'position','ROSTERSTATUS':'rosterstatus','FROM_YEAR':'from_year','TO_YEAR':'to_year','DRAFT_YEAR':'draft_year','DRAFT_ROUND':'draft_round','DRAFT_NUMBER':'draft_number'},inplace=True)

# %%
players['birthdate'] = players['birthdate'].astype('datetime64')

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485 entries, 0 to 484
# Data columns (total 13 columns):
# player_id       485 non-null int64
# full_name       485 non-null object
# birthdate       485 non-null datetime64[ns]
# country         485 non-null object
# height          485 non-null object
# weight          485 non-null object
# position        485 non-null object
# rosterstatus    485 non-null object
# from_year       483 non-null float64
# to_year         483 non-null float64
# draft_year      485 non-null object
# draft_round     485 non-null object
# draft_number    484 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(9)
# memory usage: 49.3+ KB

# %%
players.head(20)
# Out:
#     player_id          full_name  birthdate             country height weight  \
# 0      201939      Stephen Curry 1988-03-14                 USA    6-3    190
# 1      201566  Russell Westbrook 1988-11-12                 USA    6-3    200
# 2      101108         Chris Paul 1985-05-06                 USA    6-0    175
# 3        2544       LeBron James 1984-12-30                 USA    6-8    250
# 4      201933      Blake Griffin 1989-03-16                 USA   6-10    250
# 5      202330     Gordon Hayward 1990-03-23                 USA    6-8    225
# 6      200768         Kyle Lowry 1986-03-25                 USA    6-1    196
# 7      201935       James Harden 1989-08-26                 USA    6-5    220
# 8      202331        Paul George 1990-05-02                 USA    6-9    220
# 9      201144        Mike Conley 1987-10-11                 USA    6-1    175
# 10     201142       Kevin Durant 1988-09-29                 USA    6-9    240
# ...

# %%
i=0
for height in players['height']:
    if height != '':
        players['height'][i] = players['height'][i].replace('-','.')
    i += 1
# Out:
# /usr/local/Cellar/ipython/7.2.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
players.head()
# Out:
#    player_id          full_name  birthdate country height weight position  \
# 0     201939      Stephen Curry 1988-03-14     USA    6.3    190    Guard
# 1     201566  Russell Westbrook 1988-11-12     USA    6.3    200    Guard
# 2     101108         Chris Paul 1985-05-06     USA    6.0    175    Guard
# 3       2544       LeBron James 1984-12-30     USA    6.8    250  Forward
# 4     201933      Blake Griffin 1989-03-16     USA   6.10    250  Forward
#
#   rosterstatus  from_year  to_year draft_year draft_round draft_number
# 0       Active     2009.0   2018.0       2009           1            7
# 1       Active     2008.0   2018.0       2008           1            4
# 2       Active     2005.0   2018.0       2005           1            4
# 3       Active     2003.0   2018.0       2003           1            1
# 4       Active     2009.0   2018.0       2009           1            1

# %%
players['height'] = pd.to_numeric(players['height'])

# %%
players['weight'] = pd.to_numeric(players['weight'])

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485 entries, 0 to 484
# Data columns (total 13 columns):
# player_id       485 non-null int64
# full_name       485 non-null object
# birthdate       485 non-null datetime64[ns]
# country         485 non-null object
# height          445 non-null float64
# weight          445 non-null float64
# position        485 non-null object
# rosterstatus    485 non-null object
# from_year       483 non-null float64
# to_year         483 non-null float64
# draft_year      485 non-null object
# draft_round     485 non-null object
# draft_number    484 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(7)
# memory usage: 49.3+ KB

# %%
players['from_year'] = players['from_year'].fillna(0)

# %%
players['from_year'] = players['from_year'].astype('int64')

# %%
players['to_year'] = players['to_year'].fillna(0)

# %%
players['to_year'] = players['to_year'].astype('int64')

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485 entries, 0 to 484
# Data columns (total 13 columns):
# player_id       485 non-null int64
# full_name       485 non-null object
# birthdate       485 non-null datetime64[ns]
# country         485 non-null object
# height          445 non-null float64
# weight          445 non-null float64
# position        485 non-null object
# rosterstatus    485 non-null object
# from_year       485 non-null int64
# to_year         485 non-null int64
# draft_year      485 non-null object
# draft_round     485 non-null object
# draft_number    484 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(7)
# memory usage: 49.3+ KB

# %%
players['draft_year'] = players['draft_year'].replace('Undrafted','0')

# %%
players['draft_year'] = players['draft_year'].astype('int64')

# %%
players['draft_round'] = players['draft_round'].replace('Undrafted','0')

# %%
players['draft_round'] = players['draft_round'].astype('int64')

# %%
players['draft_number'] = players['draft_number'].replace('Undrafted','0')

# %%
players['draft_number'] = players['draft_number'].replace('None','0')

# %%
players['draft_number'] = players['draft_number'].fillna(0)

# %%
players['draft_number'] = players['draft_number'].astype('int64')

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485 entries, 0 to 484
# Data columns (total 13 columns):
# player_id       485 non-null int64
# full_name       485 non-null object
# birthdate       485 non-null datetime64[ns]
# country         485 non-null object
# height          445 non-null float64
# weight          445 non-null float64
# position        485 non-null object
# rosterstatus    485 non-null object
# from_year       485 non-null int64
# to_year         485 non-null int64
# draft_year      485 non-null int64
# draft_round     485 non-null int64
# draft_number    485 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(6), object(4)
# memory usage: 49.3+ KB

# %%
players.head()
# Out:
#    player_id          full_name  birthdate country  height  weight position  \
# 0     201939      Stephen Curry 1988-03-14     USA     6.3   190.0    Guard
# 1     201566  Russell Westbrook 1988-11-12     USA     6.3   200.0    Guard
# 2     101108         Chris Paul 1985-05-06     USA     6.0   175.0    Guard
# 3       2544       LeBron James 1984-12-30     USA     6.8   250.0  Forward
# 4     201933      Blake Griffin 1989-03-16     USA     6.1   250.0  Forward
#
#   rosterstatus  from_year  to_year  draft_year  draft_round  draft_number
# 0       Active       2009     2018        2009            1             7
# 1       Active       2008     2018        2008            1             4
# 2       Active       2005     2018        2005            1             4
# 3       Active       2003     2018        2003            1             1
# 4       Active       2009     2018        2009            1             1

# %%
players.to_sql('players', con=engine,if_exists='replace', index=True)

# %% [markdown]
# # Cleaning 'Teams'

# %%
teams = pd.read_sql('teams',con=engine)

# %%
teams = teams.drop(columns='index')

# %%
teams.head()
# Out:
#       TEAM_ID TEAM_NAME TEAM_ABBREVIATION TEAM_CODE      TEAM_CITY
# 0  1610612744  Warriors               GSW  warriors   Golden State
# 1  1610612760   Thunder               OKC   thunder  Oklahoma City
# 2  1610612745   Rockets               HOU   rockets        Houston
# 3  1610612747    Lakers               LAL    lakers    Los Angeles
# 4  1610612765   Pistons               DET   pistons        Detroit

# %%
teams.rename(columns={'TEAM_ID':'team_id','TEAM_NAME':'team_name','TEAM_ABBREVIATION':'team_abbreviation','TEAM_CODE':'team_code','TEAM_CITY':'team_city'},inplace=True)

# %%
teams.head()
# Out:
#       team_id team_name team_abbreviation team_code      team_city
# 0  1610612744  Warriors               GSW  warriors   Golden State
# 1  1610612760   Thunder               OKC   thunder  Oklahoma City
# 2  1610612745   Rockets               HOU   rockets        Houston
# 3  1610612747    Lakers               LAL    lakers    Los Angeles
# 4  1610612765   Pistons               DET   pistons        Detroit

# %%
teams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
# team_id              32 non-null int64
# team_name            32 non-null object
# team_abbreviation    32 non-null object
# team_code            32 non-null object
# team_city            32 non-null object
# dtypes: int64(1), object(4)
# memory usage: 1.3+ KB

# %%
teams = teams.drop(index=10).reset_index().drop(columns='index')

# %%
teams
# Out:
#        team_id      team_name team_abbreviation     team_code      team_city
# 0   1610612744       Warriors               GSW      warriors   Golden State
# 1   1610612760        Thunder               OKC       thunder  Oklahoma City
# 2   1610612745        Rockets               HOU       rockets        Houston
# 3   1610612747         Lakers               LAL        lakers    Los Angeles
# 4   1610612765        Pistons               DET       pistons        Detroit
# 5   1610612738        Celtics               BOS       celtics         Boston
# 6   1610612761        Raptors               TOR       raptors        Toronto
# 7   1610612763      Grizzlies               MEM     grizzlies        Memphis
# 8   1610612743        Nuggets               DEN       nuggets         Denver
# 9   1610612757  Trail Blazers               POR       blazers       Portland
# 10  1610612759          Spurs               SAS         spurs    San Antonio
# ...

# %%
teams.to_sql('teams', con=engine,if_exists='replace', index=True)

# %% [markdown]
# # Cleaning 'performance'

# %%
perf = pd.read_sql('performance',con=engine)

# %%
perf = perf.drop(columns='index')

# %%
perf.head()
# Out:
#    PLAYER_ID        PLAYER_NAME TimeFrame   PTS   AST   REB    PIE
# 0     201566  Russell Westbrook   2018-19  22.9  10.5  11.1  0.161
# 1     101108         Chris Paul   2018-19  15.7   8.2   4.6  0.137
# 2       2544       LeBron James   2018-19  27.5   8.0   8.5  0.190
# 3     201933      Blake Griffin   2018-19  24.7   5.4   7.6  0.153
# 4     202330     Gordon Hayward   2018-19  10.8   3.4   4.3  0.108

# %%
perf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478 entries, 0 to 477
# Data columns (total 7 columns):
# PLAYER_ID      478 non-null int64
# PLAYER_NAME    478 non-null object
# TimeFrame      478 non-null object
# PTS            478 non-null float64
# AST            478 non-null float64
# REB            478 non-null float64
# PIE            452 non-null float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 26.2+ KB

# %%
perf.isna().sum()
# Out:
# PLAYER_ID       0
# PLAYER_NAME     0
# TimeFrame       0
# PTS             0
# AST             0
# REB             0
# PIE            26
# dtype: int64

# %%
perf = perf[perf['PIE'].notna()]

# %%
perf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 452 entries, 0 to 477
# Data columns (total 7 columns):
# PLAYER_ID      452 non-null int64
# PLAYER_NAME    452 non-null object
# TimeFrame      452 non-null object
# PTS            452 non-null float64
# AST            452 non-null float64
# REB            452 non-null float64
# PIE            452 non-null float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 28.2+ KB

# %%
perf.head()
# Out:
#    PLAYER_ID        PLAYER_NAME TimeFrame   PTS   AST   REB    PIE
# 0     201566  Russell Westbrook   2018-19  22.9  10.5  11.1  0.161
# 1     101108         Chris Paul   2018-19  15.7   8.2   4.6  0.137
# 2       2544       LeBron James   2018-19  27.5   8.0   8.5  0.190
# 3     201933      Blake Griffin   2018-19  24.7   5.4   7.6  0.153
# 4     202330     Gordon Hayward   2018-19  10.8   3.4   4.3  0.108

# %%
perf.rename(columns={'PLAYER_ID':'player_id','PLAYER_NAME':'player_name','TimeFrame':'timeframe','PTS':'pts','AST':'ast','REB':'reb','PIE':'pie'},inplace=True)

# %%
perf.head()
# Out:
#    player_id        player_name timeframe   pts   ast   reb    pie
# 0     201566  Russell Westbrook   2018-19  22.9  10.5  11.1  0.161
# 1     101108         Chris Paul   2018-19  15.7   8.2   4.6  0.137
# 2       2544       LeBron James   2018-19  27.5   8.0   8.5  0.190
# 3     201933      Blake Griffin   2018-19  24.7   5.4   7.6  0.153
# 4     202330     Gordon Hayward   2018-19  10.8   3.4   4.3  0.108

# %%
i=0
for season in perf['timeframe']:
    perf['timeframe'][i] = season.replace('2018-19','2018/19')
    i+=1

# %%
perf[perf['player_name']=='Anthony Davis']['timeframe']
# Out:
# 20    2018-19
# Name: timeframe, dtype: object

# %%
perf['timeframe'] = perf['timeframe'].replace('2018-19','2018/19')

# %%
perf
# Out:
#      player_id             player_name timeframe   pts   ast   reb    pie
# 0       201566       Russell Westbrook   2018/19  22.9  10.5  11.1  0.161
# 1       101108              Chris Paul   2018/19  15.7   8.2   4.6  0.137
# 2         2544            LeBron James   2018/19  27.5   8.0   8.5  0.190
# 3       201933           Blake Griffin   2018/19  24.7   5.4   7.6  0.153
# 4       202330          Gordon Hayward   2018/19  10.8   3.4   4.3  0.108
# 5       200768              Kyle Lowry   2018/19  14.8   9.0   4.8  0.117
# 6       201935            James Harden   2018/19  35.9   7.6   6.4  0.195
# 7       202331             Paul George   2018/19  28.3   4.2   8.2  0.165
# 8       201144             Mike Conley   2018/19  20.7   6.4   3.4  0.150
# 9       201142            Kevin Durant   2018/19  27.4   5.6   6.7  0.164
# 10      200794            Paul Millsap   2018/19  13.0   1.9   7.2  0.119
# 11      201143              Al Horford   2018/19  13.0   4.1   6.7  0.129
# ...

# %%
perf.to_sql('performance', con=engine,if_exists='replace', index=True)
