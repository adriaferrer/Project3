# %%
from nba_api.stats.endpoints import commonplayerinfo
from nba_api.stats.endpoints import leaguedashplayerbiostats
from nba_api.stats.endpoints import teamdetails
from nba_api.stats.static import teams
from nba_api.stats.static import players
import pandas as pd
import time

# %%
player_info = commonplayerinfo.CommonPlayerInfo(player_id=2544)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-ad3071eee394> in <module>
# ----> 1 player_info = commonplayerinfo.CommonPlayerInfo(player_id=2544)
#
# /usr/local/lib/python3.7/site-packages/nba_api/stats/endpoints/commonplayerinfo.py in __init__(self, player_id, league_id_nullable)
# ...

# %%
player_info.common_player_info.get_data_frame()

# %%
players = pd.DataFrame(players.get_players())

# %%
players.sample(5)

# %%
players.shape

# %%
players[players['id'] == 203518]

# %%
"""total_players = pd.DataFrame()
i = 0

for player in players['id'][0:1]:
    #time.sleep(0.01)
    player_info = commonplayerinfo.CommonPlayerInfo(player_id=str(player))
    temporal_df = player_info.common_player_info.get_data_frame()
    if i == 0:
        total_players = temporal_df
        i += 1
    else:
        total_players = total_players.append(temporal_df)
        i += 1"""

# %%
total_players.head()

# %%
total_players.columns

# %%
teams.find_team_name_by_id('1610612742')

# %%
equipos = players = pd.DataFrame(teams.get_teams())

# %%
bio_stats = leaguedashplayerbiostats.LeagueDashPlayerBioStats().get_data_frames()[0]

# %%
bio_stats.columns

# %%
equipos
# Out:
#    abbreviation           city               full_name          id  \
# 0           ATL        Atlanta           Atlanta Hawks  1610612737
# 1           BOS         Boston          Boston Celtics  1610612738
# 2           CLE      Cleveland     Cleveland Cavaliers  1610612739
# 3           NOP    New Orleans    New Orleans Pelicans  1610612740
# 4           CHI        Chicago           Chicago Bulls  1610612741
# 5           DAL         Dallas        Dallas Mavericks  1610612742
# 6           DEN         Denver          Denver Nuggets  1610612743
# 7           GSW   Golden State   Golden State Warriors  1610612744
# 8           HOU        Houston         Houston Rockets  1610612745
# 9           LAC    Los Angeles    Los Angeles Clippers  1610612746
# 10          LAL    Los Angeles      Los Angeles Lakers  1610612747
# 11          MIA          Miami              Miami Heat  1610612748
# 12          MIL      Milwaukee         Milwaukee Bucks  1610612749
# ...

# %%
team_info = teamdetails.TeamDetails('1610612738')

# %%
prueba = team_info.get_data_frames()

# %%
jugadores_equipo = pd.DataFrame()
for ids in equipos['id'][:]:
    print(f'Empezando equipo {ids}')
    team_info = teamdetails.TeamDetails(str(ids))
    prueba = team_info.get_data_frames()
    prueba[6]['Team_ID'] = prueba[1].TEAM_ID[0]
    prueba[7]['Team_ID'] = prueba[1].TEAM_ID[0]
    jugadores_equipo = jugadores_equipo.append(prueba[6])
    jugadores_equipo = jugadores_equipo.append(prueba[7])
    print(f'Equipo {ids} terminado')
# Out:
# Empezando equipo 1610612737
# Equipo 1610612737 terminado
# Empezando equipo 1610612738
# Equipo 1610612738 terminado
# Empezando equipo 1610612739
# Equipo 1610612739 terminado
# Empezando equipo 1610612740
# Equipo 1610612740 terminado
# Empezando equipo 1610612741
# Equipo 1610612741 terminado
# Empezando equipo 1610612742
# Equipo 1610612742 terminado
# Empezando equipo 1610612743
# Equipo 1610612743 terminado
# Empezando equipo 1610612744
# Equipo 1610612744 terminado
# Empezando equipo 1610612745
# Equipo 1610612745 terminado
# Empezando equipo 1610612746
# Equipo 1610612746 terminado
# Empezando equipo 1610612747
# Equipo 1610612747 terminado
# Empezando equipo 1610612748
# Equipo 1610612748 terminado
# Empezando equipo 1610612749
# Equipo 1610612749 terminado
# Empezando equipo 1610612750
# Equipo 1610612750 terminado
# Empezando equipo 1610612751
# Equipo 1610612751 terminado
# Empezando equipo 1610612752
# Equipo 1610612752 terminado
# Empezando equipo 1610612753
# ...

# %%
jugadores_equipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 495 entries, 0 to 1
# Data columns (total 7 columns):
# PLAYERID           468 non-null float64
# PLAYER             495 non-null object
# POSITION           493 non-null object
# JERSEY             205 non-null object
# SEASONSWITHTEAM    491 non-null object
# YEAR               477 non-null float64
# Team_ID            495 non-null int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 30.9+ KB

# %%
prueba[6]['Team_ID'] = prueba[1].TEAM_ID[0]
prueba[7]['Team_ID'] = prueba[1].TEAM_ID[0]
prueba_vacia8 = pd.concat([prueba[6],prueba[7]])

# %%
prueba_vacia8.to_csv('team_players.csv')

# %%
prueba_vacia8['Team_ID'] = prueba_vacia1.TEAM_ID[0]

# %%
prueba_vacia8
# Out:
#     PLAYERID                 PLAYER               POSITION JERSEY  \
# 0    78097.0          Charlie Scott                      G   None
# 1      129.0             Dino Radja                    F-C   None
# 2      951.0              Ray Allen                      G   None
# 3      406.0       Shaquille O'Neal                      C   None
# 4    78510.0            Jo Jo White                      G   None
# 5   600014.0          Artis Gilmore                      C   None
# 6    77141.0         Dennis Johnson                      G   None
# 7     1122.0      Dominique Wilkins                      F   None
# 8      305.0          Robert Parish                      C   None
# 9    77498.0             Bob McAdoo                    C/F   None
# 10    1450.0           Kevin McHale                      F   None
# 11   77967.0            Arnie Risen                      C   None
# 12    1449.0             Larry Bird                      F   None
# ...

# %%
team_players = pd.DataFrame()
i = 0

for team in equipos['id'][0:2]:
    #time.sleep(0.01)
    team_info = teamdetails.TeamDetails.get_data_frames()
    player_info = commonplayerinfo.CommonPlayerInfo(player_id=str(player))
    temporal_df = player_info.common_player_info.get_data_frame()
    if i == 0:
        total_players = temporal_df
        i += 1
    else:
        total_players = total_players.append(temporal_df)
        i += 1
