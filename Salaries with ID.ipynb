# %%
from nba_api.stats.endpoints import commonplayerinfo
from nba_api.stats.endpoints import leaguedashplayerbiostats
from nba_api.stats.static import teams
from nba_api.stats.static import players
import pandas as pd
import time

# %%
player_info = commonplayerinfo.CommonPlayerInfo(player_id=2544)

# %%
player_info.common_player_info.get_data_frame()
# Out:
#    PERSON_ID FIRST_NAME LAST_NAME DISPLAY_FIRST_LAST DISPLAY_LAST_COMMA_FIRST  \
# 0       2544     LeBron     James       LeBron James            James, LeBron
#
#   DISPLAY_FI_LAST            BIRTHDATE                        SCHOOL COUNTRY  \
# 0        L. James  1984-12-30T00:00:00  St. Vincent-St. Mary HS (OH)     USA
#
#                    LAST_AFFILIATION  ...    TEAM_CITY    PLAYERCODE  \
# 0  St. Vincent-St. Mary HS (OH)/USA  ...  Los Angeles  lebron_james
#
#    FROM_YEAR TO_YEAR DLEAGUE_FLAG NBA_FLAG  GAMES_PLAYED_FLAG DRAFT_YEAR  \
# 0       2003    2018            N        Y                  Y       2003
#
#   DRAFT_ROUND DRAFT_NUMBER
# 0           1            1
#
# [1 rows x 30 columns]

# %%
players = pd.DataFrame(players.get_players())

# %%
players.sample(5)
# Out:
#      first_name      full_name      id last_name
# 965      Gorgui   Gorgui Dieng  203476     Dieng
# 4064         TJ      TJ Warren  203933    Warren
# 3240      Kevin  Kevin Restani   77944   Restani
# 4011      Danny   Danny Wagner   78428    Wagner
# 666         Rex    Rex Chapman     364   Chapman

# %%
players.shape
# Out:
# (4374, 4)

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://root:paugasol@35.246.57.187/NBA')

# %%
df_players_salaries = pd.read_sql('salaries',con=engine)

# %%
df_players_salaries.head()
# Out:
#    index          Full name      2018/19      2019/20      2020/21  \
# 0      0      Stephen Curry  $37,457,154  $40,231,758  $43,006,362
# 1      1  Russell Westbrook  $35,665,000  $38,150,000  $40,600,000
# 2      2         Chris Paul  $35,654,150  $38,506,482  $41,358,814
# 3      3       LeBron James  $35,654,150  $37,436,858  $39,219,566
# 4      4      Blake Griffin  $31,873,932  $34,234,964  $36,595,996
#
#        2021/22 2022/23 2023/24
# 0  $45,780,966      $0      $0
# 1                           $0
# 2  $44,211,146      $0      $0
# 3  $41,002,274      $0      $0
# 4  $38,957,028      $0      $0

# %%
df_players_salaries = df_players_salaries.merge(players, left_on='Full name',right_on = 'full_name')

# %%
df_players_salaries.head()
# Out:
#    index          Full name      2018/19      2019/20      2020/21  \
# 0      0      Stephen Curry  $37,457,154  $40,231,758  $43,006,362
# 1      1  Russell Westbrook  $35,665,000  $38,150,000  $40,600,000
# 2      2         Chris Paul  $35,654,150  $38,506,482  $41,358,814
# 3      3       LeBron James  $35,654,150  $37,436,858  $39,219,566
# 4      4      Blake Griffin  $31,873,932  $34,234,964  $36,595,996
#
#        2021/22 2022/23 2023/24 first_name          full_name      id  \
# 0  $45,780,966      $0      $0    Stephen      Stephen Curry  201939
# 1                           $0    Russell  Russell Westbrook  201566
# 2  $44,211,146      $0      $0      Chris         Chris Paul  101108
# 3  $41,002,274      $0      $0     LeBron       LeBron James    2544
# 4  $38,957,028      $0      $0      Blake      Blake Griffin  201933
#
#    last_name
# 0      Curry
# 1  Westbrook
# 2       Paul
# 3      James
# 4    Griffin

# %%
df_players_salaries.shape
# Out:
# (485, 12)

# %%
df_players_salaries.drop(columns=['index','first_name','full_name','last_name'],inplace=True)

# %%
df_players_salaries.isna().sum()
# Out:
# Full name    0
# 2018/19      0
# 2019/20      0
# 2020/21      0
# 2021/22      0
# 2022/23      0
# 2023/24      0
# id           0
# dtype: int64

# %%
df_players_salaries
# Out:
#                   Full name      2018/19      2019/20      2020/21  \
# 0             Stephen Curry  $37,457,154  $40,231,758  $43,006,362
# 1         Russell Westbrook  $35,665,000  $38,150,000  $40,600,000
# 2                Chris Paul  $35,654,150  $38,506,482  $41,358,814
# 3              LeBron James  $35,654,150  $37,436,858  $39,219,566
# 4             Blake Griffin  $31,873,932  $34,234,964  $36,595,996
# 5            Gordon Hayward  $31,214,295  $32,700,690  $34,187,085
# 6                Kyle Lowry  $31,000,000  $33,296,296           $0
# 7              James Harden  $30,570,000  $38,150,000  $40,600,000
# 8               Paul George  $30,560,700  $33,005,556  $35,450,412
# 9               Mike Conley  $30,521,115  $32,511,623  $34,502,130
# 10             Kevin Durant  $30,000,000  $31,500,000           $0
# 11             Paul Millsap  $29,230,769  $30,000,000           $0
# 12               Al Horford  $28,928,710  $30,123,015           $0
# ...

# %%
df_players_salaries.to_sql('salaries', con=engine, if_exists='replace')
